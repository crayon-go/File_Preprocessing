# %% [markdown]
# ### 한글 폴더명 변경

# %%
import os
import random
import shutil
from tqdm.notebook import tqdm

# %%
# 상품 루트 폴더
root_folder = "D:\\사용할 이미지"
cate_folders = os.listdir(root_folder)

size_list = []
roll_list = [1, 2, 3, 4, 22, 23, 24]

for cate_folder in tqdm(cate_folders):

    print("\n>> Category : " + cate_folder)

    # 카테고리 기준 확인
    item_folders = os.listdir(root_folder + "\\" + cate_folder)

    for item_folder in tqdm(item_folders):
        folder_path = os.path.join(root_folder, cate_folder,item_folder)
        files = os.listdir(folder_path)

        print(item_folder)

print("\n>> DONE <<")
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# >> Category : 과자
#   0%|          | 0/21 [00:00<?, ?it/s]
# 15626_농심켈로그프링글스또띠아콘칩스파이시그린페퍼110G
# 20126_농심)프링글스클래식110G
# 20127_프링글스치즈맛110G
# 20128_농심)프링글스버터캬라멜110G
# 20129_켈로그)프링글스사워크림_어니언
# 25181_농심켈로그)프링글스마늘감자구이맛110G
# 25647_레딕스글로비즈릴레레몬향쿠키130G
# 25648_레딕스글로비즈릴레클래식오리지날쿠키130G
# 25649_레딕스글로비즈릴레초코향쿠키130G
# 25650_레딕스글로비즈돌체토롤와퍼티라미슈맛85G
# 45167_농심켈로그)프링글스블로네제스파게티맛110G
# 45168_농심켈로그)프링글스사워크림앤어니언100G
# 60131_프링글스마요치즈맛110G
# 60132_농심)프링글스할라피뇨110G
# 65199_켈로그프링글스찹스테이크
# 65200_켈로그프링글스크리미쉬림프
# 70110_해태초코픽45G
# 70142_프링글스WTF110G
# 70143_농심)프링글스블랙페퍼크랩110G
# 80117_프링글스핫스파이시110G
# 90293_프링글스또띠아나쵸치즈110G
#
# >> Category : 디저트
#   0%|          | 0/4 [00:00<?, ?it/s]
# 10242_Dole후룻볼슬라이스복숭아198g
# 35587_돌코리아망고컵198G
# 45030_돌황도666G
# 55034_돌트로피칼666G
#
# >> Category : 면류
#   0%|          | 0/32 [00:00<?, ?it/s]
# 10101_농심오징어짬뽕컵67G
# 10102_농심신라면컵65G
# 10103_오뚜기참깨라면(컵)
# 15825_오뚜기컵누들팟타이쌀국수50G
# 15829_오뚜기진라면매운맛컵110G
# 15831_오뚜기진라면순한맛컵110G
# 15832_오뚜기오동통면컵100G
# 15836_오뚜기열라면컵105G
# 15838_오뚜기육개장컵110G
# 20113_농심짜파게티큰사발123G
# 20114_삼양)까르보불닭볶음면큰컵105G
# 25053_농심너구리큰사발면111G
# 25853_농심순한너구리컵63G
# 35225_농심)신라면블랙101G
# 40103_오뚜기진진짜라120G
# 40104_오뚜기크림진짬뽕105G
# 45169_농심)사리곰탕컵61G
# 45175_키다리식품)세이면김치194G
# 55023_농심신라면두부김치94G
# 55041_농심짜왕큰사발면
# 60094_삼양라면110g
# 60095_오뚜기)쇠고기미역국라면100G
# 60108_농심새우탕큰사발115G
# 60110_오뚜기스낵면컵
# 60115_오뚜기진라면컵순65G
# 60118_오뚜기진라면매운맛65G(작은용기)
# 75048_농심튀김우동컵62G
# 90086_농심무파마큰사발112G
# 90087_농심우육탕큰사발115G
# 90128_오뚜기참깨라면용기110G
# A20026_종가집)멸치쌀국수
# A40029_농심쌀국수
#
# >> Category : 미분류
# 0it [00:00, ?it/s]
# >> Category : 상온HMR
#   0%|          | 0/26 [00:00<?, ?it/s]
# 25710_CJ백설건강발효현미식초500ML
# 25711_CJ사골애처음부터육수가쓰오525ML
# 26011_CJ밸런스밀귀리50G
# 26013_지오허브팔각향80G
# 35629_늘푸른농업)볶은아마씨
# 35640_두리두리)인절미가루
# 35676_페레로)누텔라
# 45695_두리두리)구운완두콩
# 45696_두리두리)구운수수
# 56003_엄마사랑)차가버섯분말
# 56004_청화농산)흑임자볶음깨
# 65634_에스피씨삼립플랜터스드라이로스트피넛
# 65637_두리두리구운현미
# 65684_농업회사법인(유)광복)찰진윤기가오래지속되는화선찹쌀
# 65685_농업회사법인월드그린)오색오미
# 65686_두보식품)기장차조수수율무가30_들어있는맛있는9곡
# 65688_서울루션)햄프씨드
# 65689_수내츄럴)자연속내츄럴쌀눈
# 65819_친정엄마)볶음검정깨
# 75018_광복)베타원찰보리쌀
# 75051_보라티알페스토알라제노베시200G
# 75052_이마트피코크통백후추그라인더60G
# 75054_이마트피코크이탈리안허브믹스20G
# 75056_이마트피코크통백후추60G
# 75058_이마트피코크파슬리7G
# 75059_이마트피코크통흑후추50G
#
# >> Category : 생활용품
#   0%|          | 0/6 [00:00<?, ?it/s]
# 20277_고후레쉬리바이브바디워시
# 55337_에프킬라무향수성
# 55354_프릴시크릿오브베이킹소다주방세제그린허브향
# 65164_불스원)레인오케이김서림방지스프레이280ML
# 66036_트랜드아이)페브클린섬유탈취제49상큼달콤한
# 66466_엘시시)입속미인스피아민트향260ML
#
# >> Category : 소스
#   0%|          | 0/112 [00:00<?, ?it/s]
# 10191_오뚜기볶음참깨100G
# 10193_백설소갈비양념290G
# 10205_오뚜기3배사과식초500ml
# 10206_해찬들새콤달콤초고추장300G
# 10207_오뚜기)올리고당700G
# 10229_오뚜기사과식초500ML
# 10296_CJ백설맛술로즈마리500ML
# 15074_유동골뱅이무침양념320G
# 15079_큐원트루스위트알룰로스올리고당12칼로리700G
# 15080_홈플러스시그니처조청쌀엿1.2KG
# 15325_효성알프레도로스티드갈릭소스410G
# 15329_폰타나카르니아베이컨앤머쉬룸크림430G
# 20130_오뚜기)옛날참기름
# 20132_오뚜기)고소한참기름
# 20133_오뚜기고소한참기름160ML
# 20134_해표고소한참기름320ML
# 20135_오뚜기)향긋한들기름
# 20173_백설돼지불고기양념500G
# 20174_백설소갈비양념500G
# 20185_오뚜기)순후추45G
# 20221_오뚜기현미식초900ML
# 20291_오뚜기홀스래디쉬250G
# 25075_청정원순창만능비빔장비빔국수300G
# 25077_테라오카계란에뿌리는간장소스150ML
# 25316_백설건강발효현미식초800ML
# 25321_청정원서해안까나리액젓골드1KG
# 26021_아이배냇순간장소스비빔용190ML
# 30177_오뚜기양조식초900ML
# 30205_CJ프락토올리고당
# 30253_씨제이유자샐러드소스115G
# 30258_씨제이마카다미아캐슈넛드레싱230G
# 30263_하인즈핫도그랠리쉬375ML
# 30264_오뚜기코을슬로드레싱255G
# 30265_CJ백설맛술생강500ML
# 30266_오뚜기스파게티소스로제685G
# 35072_홈플러스)요리당1.2KG
# 35348_오뚜기스테이크소스
# 35357_마성레고스페스토바질
# 35409_크래프트하인즈코리아)하인즈허니머스타드
# 35425_시아스)오리엔탈드레싱
# 36012_롯데쇼핑)온리프라이스대두유식용유
# 40188_오뚜기)돈까스소스290G
# 40212_오뚜기2배사과식초500ML
# 40259_삼양사큐원식이섬유풍부요리올리고당(트루스위트30)
# 40274_풀무원아몬드호두드레싱110G
# 40276_씨제이참깨드레싱105G
# 40278_풀무원저지방키위드레싱235G
# 40280_대상청정원굴소스260G
# 40289_오뚜기멸치국수장국360ML
# 40312_청정원순창초고추장300G
# 45099_팔도비빔장시그니처380G
# 45288_오뚜기)코울슬로드레싱255G
# 45289_청정원)프레시마요네즈500G
# 45377_청정원)토마토맛생크림
# 45378_오뚜기)로제스파게티소스
# 45380_백설)치즈크림파스타소스
# 45381_백설)아라비아따토마토파스타소스
# 45382_청정원)포모도로파스타소스
# 45383_폰타나)볼로냐베이컨볼로네제
# 45384_폰타나)제노바치즈_크림바질페스토
# 45385_폰타나)시칠리아피칸테크림
# 45386_폰타나)시칠리아페페론치노아라비아따
# 45476_태경식품)명란마요소스
# 50247_오뚜기스파게티소스마늘양파685G
# 55071_샘표요리에센스연두275ML
# 55304_청정원햇살담은두번달여더진한진간장양조100_
# 55305_오뚜기미향
# 55326_오뚜기참깨드레싱
# 55328_미성패밀리참소스
# 55329_오뚜기허니머스타드
# 55365_백설토마토스파게티소스
# 55369_청정원알프레도파스타소스
# 55389_샘표백년동안흑초블랙베리블루베리
# 60153_샘표)양조간장501_930ML
# 60164_오뚜기허니머스타드265G
# 60221_해표해바라기유
# 60222_해표카놀라유
# 60226_CJ마늘생강기름
# 60246_대상청정원맛술830ML(생강매실)
# 60248_하인즈우스타소스355ML
# 60251_풀무원미니참깨흑임자드레싱105G
# 65265_아이배냇요술만능소스
# 65279_홈플러스해바라기씨유
# 65342_오뚜기가정에서즐기는프리미엄스위트칠리소스
# 65345_하인즈스위트렐리쉬
# 65360_폰타나크리미페퍼소스_딥소스
# 65362_에스피씨에이원스테이크소스
# 65365_진미식품THE맛있게진미소스오리지널
# 65368_오뚜기가정에서즐기는프리미엄데리야끼소스
# 65376_대상청정원햇살담은맛간장조림볶음용
# 65377_샘표맛간장조림볶음용
# 65381_샘표새미네부엌진간장
# 65824_훼미리인터내셔날)리고초코시럽
# 65828_영남코프레이션)트러플소스
# 65833_이마트)바질
# 65835_이마트)크러쉬드레드페퍼
# 65841_이마트)쿠민
# 66064_전원식품)요리하다국내산생강가루40G
# 66165_천연식품)요리하다미감
# 66183_아이배냇)순간장소스국물용
# 70178_오뚜기콩기름900ML
# 70234_오뚜기햄스프레드
# 70239_진한하인즈토마토케찹
# 70254_씨제이키위샐러드소스115G
# 70260_오뚜기홀그레인머스타드소스280G
# 90159_샘표국간장930ML
# 90169_오뚜기옛날물엿700g
# 90170_2배현미식초900ML
# 90179_오뚜기)옛날쌀엿조청700G
# 90180_오뚜기사과식초900ML
# 90264_오뚜기타타르소스245G
# 90277_대상청정원알프레도크림치즈파스타소스350G
#
# >> Category : 유제품
#   0%|          | 0/16 [00:00<?, ?it/s]
# 10256_매일바이오드링킹요커트플레인
# 15130_야쿠르트쿠퍼스프리미엄C140ML
# 15142_한국야쿠르트건강한간케어쿠퍼스프리미엄140ML
# 25129_헬리코박터프로젝트윌150ML
# 30215_남양이오트웬티즈
# 35075_서울우유)서울연유500G
# 35178_풀무원)액티비아사과130ML
# 40232_매일바이오드링킹요거트블루베리
# 45125_풀무원)풀무원다른액티비아포도130ML
# 45131_피스퇴르)안나오면쳐들어간다쾌변포도150ML
# 45132_풀무원)다논액티비아화이트130ML
# 50196_매일바이오드링킹요거트매실푸룬
# 55118_풀무원액티비아플레인
# 65125_서울우유아침에주스포도
# 90230_매일바이오드링킹요거트사과
# 90234_빙그레요구르트
#
# >> Category : 음료
#   0%|          | 0/152 [00:00<?, ?it/s]
# 10005_웅진아침햇살500ML
# 10006_웅진아침햇살180ML
# 10007_썬키스트훼미리오렌지180ML
# 10009_일화)맥콜500ML
# 10012_조지아고티카빈티지블랙390ML
# 10041_롯데잘빠진하루우엉차500ML
# 10043_광동)옥수수수염차500ML
# 10076_코카환타오렌지1.5L
# 10077_코카환타파인애플1.5L
# 10078_롯데밀키스1.5L
# 10118_레쓰비그란데라떼500ML
# 10123_하이트진로)토닉워터300ML
# 10127_웰치스그레이프500ml
# 10130_광동힘찬하루헛개차500ML
# 10133_CJ컨디션헛개100ML
# 10135_광동)비타500(병)180ML
# 15124_서울우유아침에주스자몽950ML
# 15125_풀무원아임리얼케일키위700ML
# 15146_풀무원녹즙아임리얼스트로베리700ML
# 15337_분다버그레몬라임앤비터스375ML
# 20021_해태갈배사이다500ML
# 20094_롯데마운틴듀1.5L
# 20096_코카콜라1.25L
# 20100_제주삼다수2L
# 20140_그래미여명808140ML
# 20144_동서스타벅스프라프치노281ML
# 20151_맥심)티오페에스프레소
# 20153_델몬트)골드망고180ML
# 20155_제주삼다수500ML
# 20156_동서스타벅스모카281ML
# 20220_코카토레타1.5L
# 20234_웅진빅토리아복숭아500ml
# 25131_풀무원아임리얼순수착즙오렌지700ML
# 25185_매일유업)플로리다내추럴오렌지750ML
# 25188_풀무원식품)아임프룻제주한라봉감귤800ML
# 25189_서울에프엔비)아침에주스사과950ML
# 25332_동서스타벅스더블샷에스플레소앤크림200ML
# 25333_동서스타벅스파이크플레이스로스트블랙커피200ML
# 25337_코카)스프라이트215ML
# 25339_코카)제로코카콜라215ML
# 25340_코카)스프라이트1L
# 25792_동서오션스프레이크랜베리클래식1.5L
# 25939_롯데쇼핑초이스엘청포도음료초500ML
# 25968_롯데칠성음료마스터토닉워터410ML
# 26023_롯데쇼핑파인애플착즙주스700ML
# 30010_롯데핫식스355ML
# 30011_화인바이오)지리산맑은샘물500ML
# 30012_롯데델몬트포도100_400ML
# 30014_몬스터에너지울트라355ML
# 30015_몬스터에너지그린355ML
# 30016_웅진자연은제주감귤340ML
# 30017_롯데밀키스250ML
# 30018_롯데)칸타타스위트아메리카노275ML
# 30020_롯데칸타타스위트아메리카노175ML
# 30021_몬스터에너지파이프라인펀치355ML
# 30050_코카콜라1.6L
# 30053_롯데칠성사이다1.5L
# 30055_동아포카리스웨트1.8L
# 30189_웅진하늘보리1.5L
# 30226_CJ컨디션레이디100ML
# 35119_풀무원식품)아임리얼스트로베리190ML
# 35120_풀무원식품)아임리얼순수착즙오렌지190ML
# 35121_풀무원식품)아임리얼스무디아이스트로베리190ML
# 35122_풀무원식품)아임프룻청송사과215ML
# 35123_풀무원식품)아임프유어레몬에이드270ML
# 35125_거창공장)아침에주스950ML
# 35157_서울우유)아침에주스포도950ML
# 35205_엠즈씨드)폴바셋콜드브루보틀300ML
# 35364_샘표맛있게염도낮은양조간장
# 35365_청정원순창초고추장
# 35609_아쿠아리어스골드메달스파클링애플주스296ML
# 35690_금강B_F)칸타타아메리카노
# 35704_농심)오이오차녹차
# 35714_동서식품)스타벅스프라푸치노(카라멜향)
# 35843_부루구루)부루구루콤부차레몬
# 35844_부루구루)부루구루콤부차오리지널
# 40012_롯데)2_부족할때아쿠아500ML
# 40014_농심웰치스포도355ml
# 40020_롯데)숨편한목단비국화차(PET)500ML
# 40024_롯데트레비라임300ML
# 40026_롯데)칸타타콘트라베이스콜드브루라떼500ML
# 40028_롯데핫식스더킹파워355ML
# 40034_하이트엑스트라콜드355ml
# 40038_롯데칸타타프리미엄라떼275ML
# 40042_해태)썬키스트훼미리포도180ML
# 40053_현대미에로화이바350ML
# 40059_광동우엉차500ml
# 40072_롯데트레비플레인(PET)1.2L
# 40076_한국청정음료몽베스트2L
# 40087_코카콜라)미닛메이드제주감귤1.5L
# 45126_풀무원)풀무원아임그린보리새싹150ML
# 45128_풀무원)아임프릇제주한라봉감귤215ML
# 45129_풀무원)아임유어레몬에이드700ml
# 45213_남양유업)프렌치카페로스터리에스프레소라떼250ML
# 45306_동서식품)파이크플레이스로스트블랙커피275ML
# 45664_광동)제주삼다수
# 45733_동서음료)레드불에너지드링크
# 46120_롯데쇼핑)포도착즙주스
# 46121_롯데쇼핑)석류착즙주스
# 50013_일화초정탄산수190ML
# 50022_LOTTE레쓰비마일드커피150ML
# 50032_일화초정탄산수1.5L
# 50050_코카콜라)파워에이드1.5L
# 50087_박카스F120ML
# 50178_웅진)아침햇살1.5L
# 50186_빙그레아카페라사이즈업아메리카노
# 55111_아침에주스유기농오렌지주스
# 55112_아침에주스제주감귤
# 55121_풀무원아임프룻청송사과
# 55744_동서식품)스타벅스프라푸치노
# 55753_동서식품)스타벅스시그니처초콜렛
# 55754_동서식품)스타벅스브렉퍼스트블렌드블랙커피
# 60013_오케이에프빅토리아플레인350ML
# 60014_롯데코코리치망코340ML
# 60018_빅토리아자몽350ml
# 60064_코카킨사이다1.5L
# 60068_코카콜라2L
# 65134_매일썬업100_사과
# 66011_프레시코)아임얼라이브유기농콤부차프리바이오틱스오리지날315ML
# 66044_골든라이프텍)곡물가게궁자연주의건강함리얼호박차
# 70037_랭거스오렌지449ML
# 70045_웅진헛개꿀D100ML
# 70049_롯데칠성사이다로어슈거600ML
# 70051_광동야관문야왕500ML
# 70056_롯데칠성사이다245ML
# 70211_파스퇴르야채농장
# 75025_아쿠아리어스)골드메달애플주스
# 80011_코카콜라)미닛메이드벚꽃_사과175ML
# 80019_롯데)코코리치포도340ML
# 80034_롯데제주사랑감귤500ML
# 80039_롯데트레비자몽(PET)500ML
# 80040_롯데트레비라임(PET)500ML
# 80042_롯데GS보리차
# 80047_롯데아이시스8.01L
# 80055_해태)갈아만든배1L
# 80057_비락식혜1.2L
# 80059_롯데제주사랑감귤사랑1.5L
# 80068_광동옥수수수염차1.5L
# 80070_웅진자연은사과1.5L
# 80168_코카스프라이트1.5L
# 90003_롯데)쌕쌕오렌지238ML
# 90007_썬키스트훼미리사과180ML
# 90008_칸타타콜드브루블랙275ML
# 90011_롯데)사랑초톡톡스파클링파인애플330ML
# 90012_코카환타오렌지600ML
# 90017_롯데트레비레몬(PET)500ML
# 90023_동아오로나민C120ML
# 90029_빙그레따옴백자몽포멜로235ML
# 90032_롯데)콜드오렌지250ML
# 90057_일화탑씨포도향1.5L
# 90058_롯데)2_부족할때아쿠아PET1.5L
# 90116_롯데칸타타흑당라떼275ML
#
# >> Category : 의약외품
#   0%|          | 0/13 [00:00<?, ?it/s]
# 10096_동아제약)가그린제로100ML
# 10097_동아제약)가그린후레쉬라임100ML
# 20309_나투젠)포멀비데일리손소독청결제
# 20310_존슨앤존스)리스테린헬씨브라이트
# 30288_존슨앤존스)리스테린내츄럴그린티
# 30289_동아제약)가그린어린이용딸기
# 40304_존슨앤존스)리스테린내추럴시트러스
# 40311_존슨앤존스)리스테린후레쉬버스트
# 45292_대일화학공업)대일뉴아이스쿨에어로솔200ML
# 55734_현대약품)미에로화이바
# 56001_보고신약)노니메이트100ML
# 66380_광동제약위생천75ML
# 80140_동아제약)가그린오리지널250ml
#
# >> Category : 이_미용
#   0%|          | 0/75 [00:00<?, ?it/s]
# 15148_엘지생활건강오가니스트모로코아르간오일윤기영양컨디셔너500ML
# 15152_아모레미쟝센퍼펙트세럼슈퍼리치샴푸680ML
# 15155_아모레미쟝센데미지케어로즈프로틴린스680ML
# 15156_아모레려함빛극손상케어컨디셔너500ML
# 15160_아모레려청아두피딥클렌징샴푸500ML
# 15669_에이원비앤에이치라이프4.0민트밀크트리트먼트500ML
# 15681_라이온아이깨끗해향균폼핸드솝블루밍퍼플250ML
# 15692_엘지온더바디퓨어보타닉스리프레싱시트리스베리바디워시1150ML
# 25137_두리댕기머리여울채지성두피용샴푸액400ML
# 25141_아모레미쟝센제주알로에수분샴푸780ML
# 25149_엘지오가니스트아보카도퀴노아모근영양컨디셔너500ML
# 25152_아모레해피바스정말촉촉한바디밀크450ML
# 25170_엘지생활건강)온더바디발각질벗자풋필링스프레이240ML
# 25717_헨켈코리아샤우마7블로썸오일샴푸400ML
# 25784_무궁화샤워때비누릴랙싱라벤더각질케어용바디워시700ML
# 25785_무궁화샤워때비누블루밍로즈각질케어용바디워시700ML
# 26028_아모레해피바스포에버퍼퓸바디워시허니_코코넛900G
# 26033_유니레버코리아도브뷰티너리싱바디워시1L
# 26036_아모레일리윤프레쉬모이스춰바디워시500ML
# 26037_한국존슨앤드존슨콘스타치베이비파우더200G
# 35138_아모레퍼시픽)포에버퍼품바디워시1300G
# 35537_아모레퍼시픽)댄트롤프레쉬애플샴푸(상쾌한향)
# 35601_비에스코스텍라입R3아르간헤어오일베이비파우더100ML
# 35673_아모레퍼시픽)해피바스정말달콤한바디워시
# 35973_애경)포인트딥클린휩클렌징폼
# 35976_아모레퍼시픽)해피바스솝베리오리지널버블폼
# 45138_아모레퍼시픽)려초의방프리미엄탈모증상케어샴푸490ML
# 45139_엘지생활건강)리엔보음경옥액린스500ML
# 45140_아모레퍼시픽)미장센세럼슈퍼린스컨디셔너680ML
# 45143_엘지생활건강)리엔자생공진액린스500ML
# 45151_엘지생활건강)실크페어퍼펙트샤이닝골드시크컨디셔너1200G
# 45152_아모레퍼시픽)미장센제주프로폴리스영양샴푸780ML
# 45690_라이온코리아)아이_깨끗해항균폼핸드솝순
# 45691_라이온코리아)아이_깨끗해항균폼핸드솝청포도향
# 45714_애경)케라시스모이스춰클리닉오리지널샴푸
# 55131_엘라스틴내추럴에센셜퍼퓸컨디셔너
# 55132_해피바스포에버퍼퓸바디워시(그레이프프루트_진저)
# 55133_엘라스틴퍼퓸샴푸키스더로즈
# 55135_미쟝센스칼프케어그린티샴푸
# 55136_엘라스틴피토케라틴모이스처샴푸
# 55137_미쟝센에이징케어파워베리린스
# 55138_엘라스틴아미노펩타이드케어
# 55140_니베아익스프레스바디로션
# 55164_엘지생활건강엘라스틴아미노펩타이드케어(일랑일랑자스민)
# 55628_엘지생활건강실크리페어샤이닝베이비파우더샴푸
# 55631_엘지생활건강실크리페어퍼펙트샤이닝골드실크컨디셔너
# 55668_애경말랑카우를좋아하는말랑이버블핸드워시바나나우유향
# 56008_에이디인터내셔날)오블리스런드리패브릭퍼퓸
# 56060_한국피앤지판매유한회사)팬틴프로-브이극손상케어
# 56061_한국피앤지판매유한회사)팬틴프로-브이미셀라퓨어_모이스트트리트먼트
# 56096_엔프라니)네추어비내추럴에센스모이스춰라이징바디워시
# 56099_네이처리퍼블릭)네이처리퍼블릭러브미버블배쓰앤샤워젤로맨틱피어니
# 56100_네이처리퍼블릭)네이처리퍼블릭러브비버블배쓰앤샤워젤코튼베이비
# 56103_엔프라니)네추어비내추럴에센스모이스춰라이징바디로션
# 56105_네이처리퍼블릭)퍼퓸드네이처바디워시올데이릴리
# 56106_네이처리퍼블릭)퍼퓸드네이처바디오일워시이브닝라벤더
# 56107_네이처리퍼블릭)퍼퓸드네이처바디오일워시선샤인베리
# 56108_네이처리퍼블릭)네이처리퍼블릭허브스타일링헤어젤
# 56109_네이처리퍼블릭)핸드앤네이처클린핸드솝체리블라썸
# 56110_네이처리퍼블릭)핸드앤네이처클린핸드솝망고
# 65518_해피바스매그놀리아에센스모이스처라이징바디워시
# 65541_토니모리메이크에이치디헤어로션
# 65737_헨켈코리아샤우마7허브샴푸
# 65766_헨켈코리아샤우마스포츠헤어_바디
# 66161_유니레버코리아)바세린드라이스킨리페어로션
# 66162_아모레퍼시픽)시암아로마오일바디워시
# 66170_엘지생활건강)온더바디발을씻자코튼풋샴푸
# 66474_엘지오리엔탈리엔보양진중건성샴푸430ML
# 66475_엘지오리엔탈리엔보양진컨디셔너430ML
# 66478_엘지오가니스트유칼립투스월넛바디워시190ML
# 66479_엘시시)몽글몽글거품비누상큼한레몬향400ML
# 66480_엘시시)몽글몽글거품비누새콤한석류향400ML
# 66481_엘시시)몽글몽글거품비누달콤한포도향400ML
# 75015_애경)케라시스퍼퓨머리퀸엘레강스퍼퓸린스
# 85036_온더바디로맨틱아이리스바디워시촉촉한바디워시
#
# >> Category : 주류
#   0%|          | 0/452 [00:00<?, ?it/s]
# 10054_순하리소다톡바나나355ML
# 10057_롯데)밀러(캔)473ML
# 10058_카스라이트(캔)500ML
# 10059_한라산오리지널(병)360ML
# 10115_처음처럼포켓200ML
# 10116_진로참이슬포켓200ML
# 10212_(신)카프리330ML(병)
# 10223_하이트스타우트피쳐1.6L
# 10230_좋은데이오리지널360ML(병)
# 10238_진로골드360ML
# 10239_참이슬후레쉬(병)360ML
# 10307_포천)포천쌀막걸리
# 10309_마이비어빅웨이브골든에일
# 10310_신세계스텅브루저먼레드
# 10311_인더비어데슈츠프레쉬헤이즈
# 10313_제주소주푸른밤20지픈맛
# 10314_문배주양조원문배술
# 10315_제주소주푸른밤
# 15106_비어벨트브라우펄펄스500ML
# 15107_오칼라한트레이딩베어비어위트500ML
# 15108_백운복분자와인300ML
# 15223_크루저라즈베리향(병)
# 15224_페로니나스트라즈로(병)
# 15225_크루저블루베리향(병)
# 15226_에딩거프라이(무알콜)(병)
# 15227_다다(병)
# 15228_크롬바커필스알코올프라이(무알콜)(병)
# 15229_사이공스페셜(병)
# 15241_벨코포포빅키코젤다크(캔)
# 15242_에딩거둔켈캔맥주(캔)
# 15243_에스트렐라담바르셀로나(캔)
# 15244_스텔라아르투아(캔)
# 15245_페로니나스트라즈로(캔)
# 15246_하이네켄다크비어(캔)
# 15247_아크페일에일(캔)
# 15248_호랄프리미엄필스너라거(캔)
# 15249_롱보드아일랜드라거(캔)
# 15250_클라우스탈러(병)
# 15251_바바바맥주(캔)
# 15252_스텔라아르투아(캔)
# 15253_야콥스클라우스탈러330ML
# 15634_인덜지버니니스프리처스트로베리500ML
# 15635_플래티넘크래프트맥주골목대장500ML
# 15636_서울생주조서울생막걸리750ML
# 15637_배혜정도가화성생막걸리750ML
# 15638_배상면주가심술6750ML
# 15639_배혜정도가생옥수수동동주750ML
# 15640_지평주조지평이랑이랑스파클링막걸리750ML
# 15641_신세계엘앤비더킹덤오브벨지움엑스포트1L
# 15673_브루워리윌리안벨지안바이제500ML
# 15674_브루워리윌리안벨지안에일500ML
# 15675_신세계엘앤비발리하이로맨틱나이트라거500ML
# 15676_하이트진로싱하490ML
# 15677_에이이브랜드코리아필스너우르켈500ML
# 20048_롯데처음처럼PET400ML
# 20049_참이슬후레쉬(PET)400ML
# 20050_롯데설중매소다톡330ML
# 20051_(신)롯데처음처럼순하리복숭아360ML
# 20052_(신)보해매취순(병)375ML
# 20053_(신)롯데처음처럼순한360ML
# 20054_한라산오리지널(PET)400ML
# 20055_롯데설중매골드360ML
# 20056_롯데칠성순하리유자360ML
# 20059_롯데순하리소다톡355ML
# 20060_맥스올몰트비어355ML
# 20062_테라(병)500ML
# 20063_롯데)피츠(병)640ML
# 20064_맥스올몰트비어(병)500ML
# 20065_보해복받은부라더360ML
# 20066_하이트)참나무통맑은이슬(병)300ML
# 20067_충북맑은바람360ML
# 20068_한라산순한17(병)360ML
# 20069_하이트엑스트라콜드500ML
# 20070_롯데클라우드클래식500ML
# 20071_카스후레쉬640ML(PET)
# 20072_테라(병)640ML
# 20086_하이트엑스트라콜드(병)640ML
# 20087_프리미어오비640ML
# 20097_카스라이트페트1L
# 20194_카스후레쉬큐팩1L
# 20223_보해잎새주300ML
# 20231_비어케이칭따오(병)640ml
# 20232_옐로우주류파베르넬로샤도네이(병)750ml
# 20233_옐로우주류파베르넬로시라-까베르네(병)750ml
# 20300_호프야거바이젠비어
# 20301_리얼라거찐한맥주
# 20302_하이트진로1664블랑
# 20303_국순당아이싱자몽
# 20304_서울생주조)서울생살균캔막걸리
# 20305_롯데처음처럼플렉스
# 20306_제주소주푸른밤
# 20326_베를리너500ML
# 25078_롯데진한처럼360ML
# 25079_페르노리카코리아100파이퍼스200ML
# 25080_도아가펠소넨호펜330ML
# 25092_그롤쉬넌안콜릭500ML
# 25093_홉고블린골드500ML
# 25106_인터비어프라가프리미엄필스500ML
# 25107_에스피알인터내셔날예버필스너500ML
# 25786_신세계엘앤비뉴벨지움시트라델릭텐저린아이피에이355ML
# 25787_인터비어코리아데슈츠와우자355ML
# 25933_농업회사법인고은)선운산뽕와인300ML
# 26024_비즈에프엔비코리아비어라오500ML
# 26079_비어벨트코리아볼파스엔젤맨568ML
# 26080_안동소주일품안동소주21_350ML
# 30054_하이트)필라이트클린1.6L
# 30154_롯데설중매스파클링300ML
# 30200_오비맥주카스프레시(병)640ML
# 30201_롯데칠성음료피츠슈퍼클리어(병)640ml
# 30270_제주소주푸른밤제주소주지픈맛20
# 30272_국순당)국순당막걸리쌀
# 30273_인더비어코리아트로픽오브썬더
# 30274_하이네켄데스페라도스오리지널
# 30275_신한에프앤비에페스필스너
# 30276_하이트진로써머스비사과
# 30277_조은술세종우도땅콩전통주
# 35082_디아지오코리아)스미노프아이스그린애플향275ML
# 35103_필젠스키프레즈드로이)감브리너스오리지널500ML
# 35104_인판티나)그레벤슈타이너오리지널500ML
# 35106_디아지오코리아)조니워커_레드레이블_200ML
# 35410_지평주조)지평생막걸리옛막걸리
# 35411_지평주조)지평생막걸리쌀막걸리
# 35412_아영에프비씨)돈루치아노브뤼
# 35423_아영에프비씨)리얼푸엔테드라이레드
# 35424_아영에프비씨)리얼푸엔테세미스윗레드
# 35427_아영에프비씨)돈루치아노모스카토
# 35610_배상면주가복분자음375ML
# 35612_수성고량주수성후레쉬250ML
# 35658_경주법주)화랑
# 35715_신세계엘앤비)G7까베르네소비뇽
# 35716_웰니스)프뤼스포츠
# 35717_제이엠기획)마이셀무알콜
# 35718_신세계엘앤비)발리하이로맨틱나이트라거
# 35719_오비맥주)산토리프리미엄몰트
# 35720_인터비어코리아)피어.무비.라이언스
# 35721_프로스트)이네딧담
# 35722_피코무역)라이온라거
# 35961_인디펜던트리쿼코리아)머드쉐이크초코렛향
# 35962_인디펜던트리쿼코리아)머드쉐이크에스프레소
# 35974_뮤즈인터내셔날)담레몬
# 35982_안동소주일품)안동소주일품17_
# 36003_야콥스)웨팅어프라이
# 36004_비어케이)라오샨맥주
# 36005_엠즈베버리지)프리미엄에비스
# 40060_롯데)피츠(캔)355ML
# 40063_프리미어오비355ml
# 40066_하이트)필라이트후레쉬(캔)500ML
# 40067_하이트이슬톡톡복숭아355ml
# 40069_롯데)피츠PET1L
# 40073_하이트)필라이트후레쉬(PET)1L
# 40081_롯데)진한처음처럼1.8L
# 40111_오비)구스아일랜드덕덕구스473ML
# 40112_하이네켄오리지날(캔)330ML
# 40113_기네스드레프트330ML(캔)
# 40114_산미구엘페일필젠330ML(캔)
# 40115_비어케이)칭따오500ML
# 40116_기네스드레프트440ML(캔)
# 40207_카스후레쉬큐팩1.6L(PET)
# 40209_롯데)순하리깔라만시(병)360ML
# 40217_롯데부드러운처음처럼360ML(PET)
# 40218_롯데)클라우드PET1.6L
# 40219_롯데칠성음료클라우드생드래프트(병)500ml
# 40220_롯데칠성음료클라우드오리지널(병)500ml
# 40291_신세계엘비윌리안벨지안에일
# 40292_하이트진로크로넨버그1664
# 40293_케이앤알코리아피즈블루베리사이더
# 40294_신세계엘비츄하이스위토나요구르트
# 40295_롯데칠성순하리복숭아맛소다
# 40296_아영에프앤씨미니엠
# 40297_제주와이너리제주감귤술귤로만
# 40298_신세계엘비레자멜메를로
# 40299_신세계엘비G7샤도네이
# 45078_크루저복숭아향)275ML
# 45107_디아지오코리아홉하우스13라거500ML
# 45108_비어벨트코리아템트세븐500ML
# 45109_세븐브로이전라병맥주330ML
# 45461_우리술)톡쏘는알밤동동
# 45533_신세계엘앤비)1866블랑쉬
# 45534_신세계엘앤비)186블론드
# 45535_제주맥주)제주위트에일
# 45536_제주맥주)제주펠롱에일
# 45666_산머루)감악산머루
# 45697_플래티넘크래프트맥주)대한IPA
# 45698_오비맥주)핸드앤몰트유미의위트에일
# 45699_에이치비무역)리퍼비인디아페일에일
# 45717_오비맥주)레페블론드
# 45718_비어케이)매그너스쥬시애플
# 45719_하이트진로)싱하
# 45720_신세계엘앤비)트롤브루자몽
# 45721_선인터내셔널)창맥주
# 45722_제이엠기획)비트버거드라이브(성인용)
# 45723_하이트진로)파울라너뮌헨라거
# 45724_마이비어)어쩌라거
# 45725_산미상사)산미구엘페일필젠
# 45726_오비맥주)벡스
# 45727_엠즈베버리지)삿포로프리미엄생맥주
# 45728_오비맥주)베이브그리지오위드버블스
# 45729_오비맥주)베이브레드위드버블스
# 45732_인덜지)쉐이크베이비쉐이크패션후르츠마티니
# 45734_인덜지)올슉업패션후르츠마티니
# 45736_오비맥주)베이브로제위드버블스
# 45739_크리스터파카하드셀처믹스베리
# 45740_라사그라코리아)머피스아이리쉬스타우트
# 45741_비어케이)칭따오논알콜릭
# 45742_선인터내셔널)앵그리오처드크리슾애플
# 45743_사케마루)진달래맥주
# 45747_케이비씨)듀체스드부르고뉴
# 45748_체트온)린데만스
# 45749_아영에프비씨)푸두카베르네소비뇽쉬라즈
# 45751_체트온)린데만스크릭(체리)
# 45970_금복주)소주왕금복주
# 46049_배상면주가)보리아락21
# 50051_테라(캔)500ML
# 50052_오비맥주)프리미어오비
# 50053_오비라거뉴트로(캔)355ML
# 50118_오비)필굿세븐(캔)355ML
# 50119_카스레드6.9_(캔)
# 50120_사쿠오리지널(캔)500ML
# 50121_오비)버드와이저(캔)740ML
# 50122_크로크리얼프레시(캔)500ML
# 50124_무학주류)메종장베퀴
# 50125_옐로우주류)타베르넬로비앙코프리잔테750ML
# 50126_옐로우주류)타베르넬로로사토프리잔테
# 50249_인덜리버니니
# 50250_신세계엘앤비지세븐메를로
# 50251_신세계엘앤비지세븐까베르네소비뇽
# 50252_제주맥주)제주슬라이스
# 50253_세븐브로이맥주)맥아_더
# 50254_서울장수)월매쌀막걸리
# 50255_인판티나)그레벤슈타이너오리지널
# 50256_케이앤알코리아피즈애플사이더
# 55081_비어벨트코리아캐논볼330ML
# 55082_선인터내셔널사뮤엘아담스레벨아이피에이355ML(병)
# 55083_세븐브로이양평한강에일330ML
# 55084_인디펜던트코리아케이쥐비보트카위드레몬향330ML
# 55085_비어벨트코리아울프블랑쉐
# 55086_비어벨트코리아하이와이어
# 55087_엘티케이케이오틱더블아이피에이
# 55088_비어벨트코리아브라우펄바이젠
# 55089_네오아티잔브루어리해운대
# 55090_인덜지문베어브루잉금강산골든에잉
# 55091_뮤어스라핀쿨타
# 55391_백설맛술생강
# 55651_신세계엘앤비마튼즈필제너
# 55652_신세계엘앤비마튼즈엑스포트
# 55653_신세계엘앤비더킹덤오브벨지움바이젠
# 55654_서울장수생막걸리효모가살아있는유통기한10일
# 55655_서울장홍삼장수막걸리
# 55656_남한산성소주참살이꿀막걸리
# 55712_화요17
# 55713_케이에프제이코리아공부가주순
# 55714_농업회사법인우포의아침조선주조사
# 55715_롯데칠성음료과실주용담금소주25_
# 55716_롯데칠성음료과실주용담금소주30_
# 55743_신세계엘앤비)신포니아
# 55745_신세계앤엘비)G7메를로
# 55747_오비맥주)호가든로제
# 55810_마곡동류마타워)가펠쾰시(캔)
# 55811_에이치비무역)카프치너바이스비어(캔)
# 55812_하이네켄코리아)타이거(캔)
# 60041_하이트)필라이트(캔)355ML
# 60076_테라(PET)1.6L
# 60077_롯데)피츠PET1.6L
# 60078_하이트)필라이트후레쉬(PET)1.6L
# 60079_맥스올몰트비어1.6L
# 60080_롯데부드러운처음처럼1.8L
# 60140_진로매화수300ML
# 60141_테라(유리병)330ML
# 60142_(신)롯데청하300ML
# 60143_비어케이)칭따오(병)330ML
# 60144_하이네켄330ML(병)
# 60178_카스라이트1.6LPET
# 60181_진로참이슬클래식(PET)640ML
# 60182_(신)진로참이슬클래식360ML(병)
# 60186_옐로우주류파베르넬로피노그리지오(병)750ml
# 60189_진로참이슬(PET)500ML
# 60190_옐로우주류파베르넬로비노로쏘(레드와인)(병)750ml
# 60260_제주소주푸른밤병
# 60261_신세계엘앤비미안더핑크모스카토
# 60262_신세계엘앤비레자멜샤르도네
# 60263_케이앤알코리아피즈페어사이더
# 60264_인더비어코리아스윗워터420
# 60265_제주소주푸른밤페트20지픈맛
# 60266_제주소주푸른밤페트
# 60267_국순당백세주95ML
# 60268_국순당명작복분자
# 65085_이안마케팅허니브라운355ML(병)
# 65086_롯데칠성청하드라이300ML
# 65087_페르노리카코리아발렌타인파이니스트200ML
# 65088_유니베브테넌츠라거500ML
# 65089_비어벨트하이와이어그레이프후르츠330ML
# 65090_비어벨트판타스마330ML
# 65094_엘티케이그린블레이즈아이피에이355ML
# 65095_비어벨트코리아울프파이어플라이330ML
# 65096_비어벨트코리아울프아이피에이330ML
# 65218_에이이브랜드벨코포포빅키코젤다크(병)
# 65219_오비맥주코로나엑스트라(병)
# 65220_뮤즈인터내셔날복담(병)
# 65221_케이비코리아크롬바커(병)
# 65222_오비맥주스텔라아르투아(병)
# 65223_에코에프앤비호가든(무알코올)(캔)
# 65224_오비호가든(캔)
# 65225_오비카스0.0(무알코올)(캔)
# 65226_하이트진로싱하(캔)
# 65228_마이와인즈대만망고(캔)
# 65229_에이이브랜드코리아벨코포포빅키코젤다크(캔)
# 65230_비어벨트코리아브라우하우스바이젠(캔)
# 65231_케이비코리아크롬바커(캔)
# 65232_하이네켄코리아애플폭스(캔)
# 65233_벨코포포빅키코젤넌알콜릭(캔)
# 65234_리토벨모라반(캔)
# 65235_페로니나스트라즈로(캔)
# 65236_코로나엑스트라(캔)
# 65237_크롬바커(캔)
# 65238_에스트렐라담바르셀로나(캔)
# 65239_호가든로제(캔)
# 65240_에딩거프라이(무알콜)(캔)
# 65241_볼파스엔젤맨아이피에이(캔)
# 65242_홉고블린(캔)
# 65243_브라우하우스필스너(캔)
# 65244_리토벨클래식(캔)
# 65245_생활맥주(캔)
# 65246_주부르그랜드(캔)
# 65247_레페브라운(캔)
# 65426_배혜정도가우곡생주
# 65638_세븐브로이맥주흥청망청
# 65639_신세계엘앤비발리하이로맨틱데이라거
# 65640_신세계엘앤비바르슈타이너프리미엄
# 65678_오비맥주핸드앤몰트상상페일에일
# 65701_화요)화요41
# 65702_화요)화요25
# 65769_젠니혼주류더컵
# 65792_농업회사법인금산인삼주)금산인삼주43_(병)
# 65793_명가원영농조합법인)담솔40(병)
# 65794_마이비어)롱보드아일랜드라거(병)
# 65795_화요)화요17(병)
# 65796_아영에프비씨)더보타니스트(병)
# 65798_트랜스베버리지)캄파리(병)
# 65799_디아지오코리아)스미노프™그린애플향보드카(플라스틱병)
# 65800_페르노리카코리아)말리부(플라스틱병)
# 65801_한국브라운포맨)잭다니엘스테네시허니(병)
# 65911_비엘인터내셔날)레오
# 65912_골든블루)칼스버그
# 66078_롯데칠성음료)대장부23大丈夫375ML
# 66361_하이네켄코리아)하이네켄오리지널100ML
# 66362_비어케이칭따오맥주200ML
# 66363_하이트진로테라250ML
# 66364_오비맥주)오비라거330ML
# 70048_하이트)망고링고(캔)500ML
# 70055_롯데)밀러라이트(캔)473ML
# 70057_롯데클라우드(캔)355ML
# 70058_롯데)블루문(캔)473ML
# 70059_롯데클라우드(캔)500ML
# 70060_맥스올몰트비어500ML
# 70062_오비)필굿(캔)500ML
# 70156_보해양조보해복분자375ml
# 70187_오비라거(PET)1.6L
# 70192_(신)무학좋은데이블루베리360ML
# 70196_롯데부드러운처음처럼360ML(병)
# 70202_배상면주가심술10(병)330ml
# 70271_하이네켄)에델바이스
# 70272_국순당)국순당막걸리쌀
# 70273_배상면주가)민들레대포
# 70274_빔산토코리아)호로요이그레이프
# 70275_신세계엘앤비윌리안벨지안바이젠
# 70276_빔산토코리아)호로요이피치
# 70277_국순당)려25증류소주
# 70278_제주샘술)고소리술29_
# 70279_신세계엘앤비스팀브루임페리얼아이피에이
# 70280_동아인터내셔널)에드남스고스트쉽
# 75012_배상면주가)산사춘
# 75013_서울장수주식회사)인생막걸리
# 75014_전주이강주)이강주
# 75020_신세계)칸티프로세코디오씨
# 75031_신세계엘앤비도스코파스레드750ML
# 75033_인덜지버니니스프리처레몬500ML
# 75035_서울생주조서울생밀막걸리750ML
# 75036_제주소주제주도화산암반수로만든담금주과실용1.8L
# 80021_카스500ML(캔)
# 80116_필라이트라들러(캔)355ML
# 80130_버드와이저330ML(병)
# 80131_디아지오코리아길비스보드카블루750ml
# 80132_옐로우주류)따베르넬로비노비앙코750ML
# 80133_옐로우주류)따베르넬로로마냐산지오베제750ML
# 80134_롯데)칼로로시캘리포니아레드750ML
# 80135_롯데)울프블라스이글호크퀴베브롯750ML
# 80154_하이트)필라이트크린베리(PET)1L
# 80165_하이트진로)청포도에이슬(병)360ML
# 80175_옐로우주류파베르넬로몬테풀치아노다브루조(병)750ml
# 80176_옐로우주류파베르넬로트레비아노샤토네이(병)750ml
# 80241_롯데주류스펠세이세코
# 80242_제주소주푸른밤지픈맛페트
# 80243_제주소주푸른밤페트
# 80244_에드워드러시안베어파인애플향
# 80245_오비맥주)오비라거캔
# 80246_신세계엘앤비스팀브루임페리얼스타우트
# 80247_뉴벨지움)팻타이어엠버에일
# 80266_롯데)백화수복
# 85021_신세계엘앤비바로크(화이트)빈241
# 85022_젠니혼주류치어스준마이긴죠
# 85023_배상면주가고창LB복분자음
# 85024_제주소주제주도화산암반수로만든담금주도수30도
# 85025_신세계엘앤비피치니프로세코엑스트라드라이
# 85026_유한회사금용홍성이과두주면유8년숙성
# 85028_신세계엘앤비바로크버블리샤도네이세미용
# 85030_하이트진로진로와인레드와인
# 85034_신세계엘앤비마튼즈바이젠
# 85035_국순당옛날막걸리古
# 85037_제주소주푸른밤
# 85041_오비맥주)구스아일랜드아이피에이
# 85042_오비맥주)구스아일랜드312얼반위트
# 85044_칭따오논알콜릭
# 85045_에이티엘코리아와일드베이슨블루베리망고
# 85046_에이티엘코리아와일드베이슨블랙라즈베리
# 85047_에이티엘코리아와일드베이슨스트로베리코코넛
# 85049_인덜지올슉업하와이안다이키리
# 85050_와인나라양평점바바리아0.0_
# 85051_와인나라양평점바바리아애플
# 85052_크리스터파카하드셀처그레이프후루츠텐저린
# 85053_신세계앤엘비츄하이스위토나피치
# 85054_뮤어스TEL오리지널롱드링크진_그레이프프루트
# 85055_제이엠기획비트버거레몬(성인용)
# 85056_하이네켄코리아타이거라들러레몬
# 85057_하이네켄코리아에델바이스피치
# 85058_신세계엘앤비윌리안라들러
# 85059_신세계엘앤비트롤브루레몬
# 85060_신세계엘앤비신트라애플사이더
# 90028_(신)무학트로피컬이톡소다(병)360ML
# 90033_문배술23(병)375ML
# 90034_하이트)필라이트(캔)500ML
# 90052_하이트엑스트라콜드(PET)
# 90053_테라(PET)1L
# 90054_롯데)부드러운처음처럼PET1L
# 90056_하이트맥스피쳐1L
# 90101_강서마일드에일(캔)500ML
# 90102_구미호피치에일(캔)500ML
# 90103_하이네켄(캔)500ML
# 90104_오비)버드와이저(캔)355ML
# 90105_오비)호가든(캔)330ML
# 90158_국순당백세주375ML
# 90178_진로)레드와인
# 90196_오비)필굿(PET)1.6L
# 90197_(신)진로소주360ML
# 90213_OB맥주카스프레쉬(병)500ml
# 90283_제주소주푸른밤지픈맛
# 90284_비어케이에딩거바이스비어캔맥주
# 90285_하이트진로파울라너바이스비어
# 90286_인터비어코리아스톤탠저린익스프레스
# 90287_경주법주화랑
# 90288_인덜지버니니블러쉬
# 90289_신세계엘앤비미안더모스카토
# 90290_서울생주조서울생살균캔막걸리
#
# >> Category : 커피차
#   0%|          | 0/10 [00:00<?, ?it/s]
# 15339_동서스타벅스파이크플레이스로스트스위트블랙커피275ML
# 20266_서울강릉커피블랙2_1
# 35012_보해매원500ML
# 45077_삼광식품)리얼레몬청310ML
# 45300_대상)100_자연숙성발효초사용석류250ML
# 55318_홈플러스국산매실로건강하게만든매실청
# 65005_스위스미스머쉬멜로우코코아737G
# 65006_허쉬핫초코오리지널450G
# 65097_CJ백설리얼매실청310ML
# 65098_CJ백설리얼생강청310ML
#
# >> Category : 통조림_안주
#   0%|          | 0/3 [00:00<?, ?it/s]
# 20191_오뚜기딸기잼500G
# 30153_오뚜기포도쨈500G
# 50088_솔표위청수골드액75ML
#
# >> Category : 홈클린
#   0%|          | 0/82 [00:00<?, ?it/s]
# 10228_한국피앤지)다우니고농축섬유유연제리필(베리베리와바닐라크림향1L)
# 10327_뿌리는고속코팅왁스300ML
# 15360_다우니고농축섬유유연제화이트티와릴리2L
# 15363_유한양행유한락스후레쉬2L
# 15364_유한양행유한락스레귤러1.5L
# 15365_심플러스배수관세정제2L
# 15366_유한양행유한펑크린2L
# 15367_피엔지다우니고농축섬유유연제베리베리와바닐라2L
# 15368_피엔지다우니고농축섬유유연제레몬그라스와라일락2L
# 15371_홈플러스차량겸용유리세정제660ML
# 15398_엘지홈스타뿌리는곰팡이싹
# 15399_피죤무균무때주방용
# 15856_후레스코운동화전용세제지브로500ML
# 15857_애경트리오베이킹소다를담은주방세제700ML
# 20192_옥시데톨
# 25371_유한양행암앤해머트로피컬파라다이스
# 30193_다우니퍼퓸샤인1L
# 30225_르샤트라고농축섬유유연제1L라벤더부케
# 35010_LG)세이프천연미네랄(퐁퐁)385ML
# 35233_메디앙스)B_B식기세정제-액상형750ML
# 35328_LG생활건강)샤프란케어스타일러섬유탈취제은은한향
# 35331_헨켈)프릴맑은식초산뜻한자몽향
# 35332_헨켈)프릴맑은식초상큼한라임향
# 35333_헨켈)프릴맑은식초달콤한리치향
# 35334_헨켈)프릴시크릿오브베이킹소다와일드베리향
# 35335_지에스켐)해피홈진드기제로스프레이액무향
# 35336_유한양행)유한락스도마행주용
# 35337_LG생활건강)자연퐁식기세척기전용세제파우더타입
# 35339_유한양행)유한락스욕실청소용
# 35340_유한양행)유한락스곰팡이제거제
# 35420_한국디비케이)제타매직클리너
# 35780_LG생활건강)자연퐁찌든때걱정없는솔잎
# 35781_LG생활건강)자연퐁비린내걱정없는오렌지
# 35795_유한양행)유한락스렌지후드세정제
# 40201_애경)순샘베이킹소다_피톤치드향1KG
# 45308_라이온코리아)때가쏙비트O2
# 45309_LG생활건강)자연퐁솔잎
# 45317_라이온코리아)참그린순수발효식물
# 45322_에스씨존슨코리아)윈덱스유리세정제오리지널
# 45859_애경)랩신홈백신주방용세정제
# 45860_유한양행)유한락스도마행주용
# 50155_LG생활건강온더바디바이올렛드림바디워시
# 50156_아모레퍼시픽미장센에이징케어샴푸
# 50160_애경케라시스오이스처클리닉샴푸
# 50169_LG생활건강엘라스틴피토케라틴모이스처샴푸(시어버터)
# 50170_P_G)다우니퍼퓸핫핑크블룸1L
# 50229_메디앙스B_B젖병세정제액상형
# 55434_피죤무균무때주방기름떄강력제거레몬향(주방용)(빨강)
# 55435_피죤무균무때주방기름떄강력제거레몬향(주방용)(파랑)
# 55436_엘지생활건강홈스타베이킹소다욕실_주방(하늘색)
# 55437_불스원유리크리너
# 55438_불스원물없이간편세차
# 55440_불스원고광택왁스
# 55441_불스원물왁스
# 60168_LG생활건강온더바디더내추럴아보카도바디워시
# 60169_애경하나로플러스샴푸
# 60173_애경케라시스볼륨클리닉샴푸
# 60211_애경랩신홈백신욕실용세정제
# 60239_불스원차량용실내탈취제(쿨워터향)
# 60242_성진캠도마와행주살균세제
# 65282_메디앙스비앤비젖병세정제액상형
# 65285_엘지생활건강핑크퐁베이비식초아기옷린스
# 65293_엘지생활건강핑크퐁베이비식초세탁세제
# 65300_엘지생활건강홈스타내추럭스욕실용세정제차콜바질향
# 65301_엘지생활건강홈스타내추럭스주방용세정제레몬버베나향
# 65302_엘지생활건강홈스타내추럭스욕실용세정제라벤더향
# 65378_라이온참그린매실청정설거지
# 65379_엘지생활건강메소드다목적주방세제프렌치라벤더향
# 65395_유한양행유한락스렌지후드세정제
# 65396_피죤무균무때욕실용
# 70248_엘지샤프란케어스타일러(섬유탈취제)
# 75153_리오퐁주방세제(레몬향)
# 80077_샤프란케어스타일러섬유탈취제은은한향100ML
# 80151_LG생활건강온더바디더내추럴코코넛바디워시
# 80152_LG생활건강엘라스틴아미노펩타이드케어극손상집중케어샴푸
# 80158_아모레퍼시픽해피바스내추럴정말촉촉한바디워시
# 80167_P_G)다우니엑스퍼트스포츠1L
# 80265_불스원다목적실내세정제
# 85040_상원상공)백광락스
# 90190_바르는비트220G
# 90201_LG생활건강엘라스틴마린콜라겐탱글볼륨샴푸
# A40021_(주)엘지생활건강홈스타욕실용세정제
#
# >> DONE <<

# %% [markdown]
# # 폴더명 변경

# %%
# 상품 루트 폴더
root_folder = "D:\\사용할 이미지"
cate_folders = os.listdir(root_folder)

for cate_folder in tqdm(cate_folders):

    print("\n>> Category : " + cate_folder)

    # 카테고리 기준 확인
    item_folders = os.listdir(root_folder + "\\" + cate_folder)

    for item_folder in tqdm(item_folders):
        folder_path = os.path.join(root_folder, cate_folder,item_folder)
        files = os.listdir(folder_path)

        src = folder_path
        dst = os.path.join(root_folder, cate_folder, item_folder.split("_")[0])
        os.rename(src, dst)

print("\n>> DONE <<")
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# >> Category : 과자
#   0%|          | 0/21 [00:00<?, ?it/s]
# >> Category : 디저트
#   0%|          | 0/4 [00:00<?, ?it/s]
# >> Category : 면류
#   0%|          | 0/32 [00:00<?, ?it/s]
# >> Category : 미분류
# 0it [00:00, ?it/s]
# >> Category : 상온HMR
#   0%|          | 0/26 [00:00<?, ?it/s]
# >> Category : 생활용품
#   0%|          | 0/6 [00:00<?, ?it/s]
# >> Category : 소스
#   0%|          | 0/112 [00:00<?, ?it/s]
# >> Category : 유제품
#   0%|          | 0/16 [00:00<?, ?it/s]
# >> Category : 음료
#   0%|          | 0/152 [00:00<?, ?it/s]
# >> Category : 의약외품
#   0%|          | 0/13 [00:00<?, ?it/s]
# >> Category : 이_미용
#   0%|          | 0/75 [00:00<?, ?it/s]
# >> Category : 주류
#   0%|          | 0/452 [00:00<?, ?it/s]
# >> Category : 커피차
#   0%|          | 0/10 [00:00<?, ?it/s]
# >> Category : 통조림_안주
#   0%|          | 0/3 [00:00<?, ?it/s]
# >> Category : 홈클린
#   0%|          | 0/82 [00:00<?, ?it/s]
# >> DONE <<
